# %%
import sys
import matplotlib.pyplot as plt

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
sys.path.append('../utils')

from plots import violin_and_cummax_round

# %%
path = f"runs/rhla/"
###
fig, ax = plt.subplots(dpi=150)
violin_and_cummax_round(ax, path)
plt.xticks(fontsize=15)
plt.xlabel('Round', fontsize=20, fontweight="bold")
plt.yticks(fontsize=15)
plt.ylabel(f'Fitness', fontsize=20, fontweight="bold")
plt.hlines(1., 0.0, 5., linestyles='--', colors='gray', linewidth=1)
plt.xlim(-0.5, 5.5)
plt.ylim(0., 10.)
plt.show()
# Out:
#      round  measurement_cost  true_score
# rep
# 0        0                 1    1.000000
# 0        1                76    2.992600
# 0        2               448    4.347123
# 0        3               814    6.256908
# 0        4              1191    7.352207
# 0        5              1570    7.352207
